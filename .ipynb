# %%
print("Lauren Caroline")
# Out:
# Lauren Caroline

# %%
first_name="Lauren" #setting Variable
last_name="Caroline"
full_name = first_name + " " + last_name
print(full_name)
# Out:
# Lauren Caroline

# %% [markdown]
# Importing Packages in python

# %%
import matplotlib.pyplot as plt

# %%
x=[5,2,3,4]

# %%
y=[1,7,4,3]

# %%
x2=[4,7,9,1]

# %%
y2=[3,6,7,9]

# %%
plt.plot(x,y,label="graph")

# %%
plt.plot(x2,y2,label="Graph2")

# %%
x=[5,2,3,4]
y=[1,7,4,3]
x2=[4,7,9,1]
y2=[3,6,7,9]
plt.plot(x,y,label="graph")
plt.plot(x2,y2,label="Graph2")

# %% [markdown]
# Pandas- importing financal data

# %%
import pandas as pd

# %%
import pandas_datareader as dr

# %%
df = dr.data.get_data_yahoo ('IBM', start='2019-01-01', end='2019-01-07') #extracting data of share based on date.
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     694     @Substitution(shared_params=fmt.common_docstring, returns=fmt.return_docstring)
#     695     def to_string(
# --> 696         self,
#     697         buf=None,
#     698         columns=None,
#
# ...

# %% [markdown]
# Plot of informaion from the internet

# %%
df["Close"].plot

# %%
df["Open"] #to get one part of the array
# Out:
# Date
# 2019-01-02    112.010002
# 2019-01-03    114.529999
# 2019-01-04    114.910004
# 2019-01-07    117.500000
# Name: Open, dtype: float64

# %%
df["Close"]
# Out:
# Date
# 2019-01-02    115.209999
# 2019-01-03    112.910004
# 2019-01-04    117.320000
# 2019-01-07    118.150002
# Name: Close, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x=df["Close"]
y=df["Open"]
plt.plot (x,y, label="IBM")

# %%
df["Volume"]
# Out:
# Date
# 2019-01-02    4239900
# 2019-01-03    4346700
# 2019-01-04    4477800
# 2019-01-07    3751200
# Name: Volume, dtype: int64

# %%
df["Open"]
# Out:
# Date
# 2019-01-02    112.010002
# 2019-01-03    114.529999
# 2019-01-04    114.910004
# 2019-01-07    117.500000
# Name: Open, dtype: float64

# %%
x2=df["Volume"]
y2=df["Open"]
plt.plot (x2,y2, label="IBM 2")
